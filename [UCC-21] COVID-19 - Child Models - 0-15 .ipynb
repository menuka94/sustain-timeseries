# %%
import pandas as pd
from prophet import Prophet
from pymongo import MongoClient
from prophet.plot import plot_plotly, plot_components_plotly
import os
import time
import pickle
from datetime import datetime
import itertools
import dask
from dask.distributed import Client
# Out:
# Importing plotly failed. Interactive plots will not work.

# %%
df_parent = pd.read_csv('covid_parents_trained.csv')
df_parent.shape
# Out:
# (56, 4)

# %%
class TrainedParent:
    def __init__(self, gis_join, rmse, changepoint_prior_scale, seasonality_prior_scale):
        self.gis_join = gis_join
        self.rmse = rmse
        self.changepoint_prior_scale = changepoint_prior_scale
        self.seasonality_prior_scale = seasonality_prior_scale
        
    def __str__(self):
        return f'{self.gis_join}: (rmse={self.rmse}, changepoint_prior_scale={self.changepoint_prior_scale}, seasonality_prior_scale={self.seasonality_prior_scale})'
    
trained_parents_map = {}  
for i, row in df_parent.iterrows():
    gis_join = row['GISJOIN']
    rmse = row['rmse']
    changepoint_prior_scale = row['changepoint_prior_scale']
    seasonality_prior_scale = row['seasonality_prior_scale']
    trained_parents_map[gis_join] = (TrainedParent(gis_join, 
                                                   rmse, changepoint_prior_scale, seasonality_prior_scale))
    
print(len(trained_parents_map.keys()))
# Out:
# 56

# %%
# Load Child Parent Map
child_parent_map = pickle.load(open('ucc-21/covid_child_parent_map.pkl', 'rb'))

# %%
# import numpy as np

# trained_parents_list = list(trained_parents_map.keys())
# loaded_parents_list = list(child_parent_map.values())
# difference = set(trained_parents_list) - set(loaded_parents_list)
# print(f'Difference: {len(difference)}')

# parents_npa = np.asarray(parents_list)

# unique_parents = np.unique(parents_npa)
# print(len(unique_parents))
# unique_parents

# %% [markdown]
# ### Original Parents
#
# G0400130, G0400190, G0400270, G0500590, G0500690, G0501030, G0600370, G0600590, G0600650, G0600710, G0600730, G0800050, G0800150, G0900090, G1200090, G1200110, G1200170, G1200830, G1201050, G1301350, G1700310, G1700430, G1701110, G1800970, G1900610, G1901010, G2405100, G2601210, G2700810, G2900950, G3000130, G3200030, G3300150, G3400030, G3500010, G3600510, G3600590, G3600910, G3900170, G3900350, G3900410, G4001090, G4200030, G4201010, G4600990, G4800270, G4800290, G4800850, G4801090, G4801130, G4801570, G4802010, G4802150, G4900350, G5100090, G5400550

# %%
df_clusters = pd.read_csv('~/ucc-21/clusters-covid.csv')
df_clusters.head()
# Out:
#    Unnamed: 0   GISJOIN  cluster_id   distance  is_parent  frac_distance  \
# 0           0  G0100010          39   7.582524        0.0       0.046117
# 1           1  G0100030          37  21.277778        0.0       0.109459
# 2           2  G0100050          47  22.647059        0.0       0.288432
# 3           3  G0100070          22  53.160338        0.0       0.611449
# 4           4  G0100090          29  55.718750        0.0       0.522091
#
#    sample_percent
# 0        0.059223
# 1        0.071892
# 2        0.107686
# 3        0.172290
# 4        0.154418

# %%
# child GISJOIN to sample_percent map
child_map = {}
for i, row in df_clusters.iterrows():
    is_parent = row['is_parent']
    sample_percent = row['sample_percent']
    if not is_parent and sample_percent <= 0.15:
        gis_join = row['GISJOIN']
        
        child_map[gis_join] = sample_percent
        
no_of_children = len(child_map.keys())
no_of_parents = len(trained_parents_map.keys())

# assert no_of_children == (df_clusters.shape[0] - no_of_parents)
print(no_of_children)
# Out:
# 1817

# %%
db = MongoClient("lattice-100", 27018)
collection = 'covid_county_formatted'

def get_df_by_gis_join(gis_join, sample_percent=1.0):
    print(gis_join, end=' ')
    cursor = db.sustaindb[collection].aggregate([{"$match": {"GISJOIN": gis_join}}])
    df = pd.DataFrame(list(cursor))[['date', 'cases']]
    df.columns = ['ds','y']
    return df.sample(frac=sample_percent)

# %%
def predict_transfer(df_train, parent_trained):
    time1 = time.monotonic()
    # initilaize model with hyperparameters from parent model
    m = Prophet(
        seasonality_prior_scale = parent_trained.seasonality_prior_scale,
        changepoint_prior_scale = parent_trained.changepoint_prior_scale,
    )
    m.fit(df_train, algorithm='LBFGS')
    df_train_future = m.make_future_dataframe(periods=300, freq='H')
    df_train_forecast = m.predict(df_train_future)
    time2 = time.monotonic()

    return m, df_train_future, df_train_forecast, (time2 - time1)


def predict_transfer_task(df_train, gis_join, parent_trained):
    m, df_train_future, df_train_forecast, time_taken = predict_transfer(df_train, parent_trained)
    return gis_join, time_taken


# child_list = []
# child_dfs_list = []

# for gis_join, sample_percent in child_map.items():
#     child_list.append(gis_join)
#     child_dfs_list.append(get_df_by_gis_join(gis_join, sample_percent))
child_list = pickle.load(open('ucc-21/child_list_0_15.pkl', 'rb'))
child_dfs_list = pickle.load(open('ucc-21/child_dfs_list_0_15.pkl', 'rb'))

# %%
print(len(child_list))
print(len(child_dfs_list))
# Out:
# 1817
# 1817

# %%
pickle.dump(child_list, open('ucc-21/temp_child_list.pkl', 'wb'))

# %%
# pickle.dump(child_list, open('ucc-21/child_list_0_15.pkl', 'wb'))
# pickle.dump(child_dfs_list, open('ucc-21/child_dfs_list_0_15.pkl', 'wb'))

# %%
client = Client('lattice-150:8786')

counter = 1
lazy_results = []
for gis_join, df_ in zip(child_list, child_dfs_list):
    try:
        parent = child_parent_map[gis_join]
        parent_trained_  = trained_parents_map[parent]
        print(parent_trained_)
        lazy_result = dask.delayed(predict_transfer_task)(df_, gis_join, parent_trained_)
        lazy_results.append(lazy_result)
    except:
        print(f'Error on {gis_join}')
    if counter % 100 == 0:
        print(counter, end=', ')
    counter += 1
#     break

futures = dask.persist(*lazy_results)  # trigger computation in the background
results = dask.compute(*futures)
results[:5]
# Out:
# Error on G0100010
# Error on G0100030
# Error on G0100050
# Error on G0100110
# Error on G0100150
# Error on G0100290
# Error on G0100310
# Error on G0100350
# Error on G0100370
# Error on G0100430
# Error on G0100470
# Error on G0100490
# Error on G0100510
# Error on G0100550
# Error on G0100570
# Error on G0100610
# Error on G0100630
# Error on G0100690
# Error on G0100710
# Error on G0100750
# Error on G0100770
# Error on G0100790
# Error on G0100830
# Error on G0100890
# Error on G0100910
# Error on G0100930
# G1701110: (rmse=56.54114220754974, changepoint_prior_scale=0.1, seasonality_prior_scale=0.01)
# Error on G0101010
# Error on G0101030
# Error on G0101050
# Error on G0101070
# Error on G0101110
# Error on G0101170
# Error on G0101190
# Error on G0101210
# Error on G0101230
# Error on G0101250
# Error on G0101310
# Error on G0200130
# Error on G0200200
# Error on G0200500
# Error on G0200680
# Error on G0200700
# Error on G0200900
# Error on G0201000
# Error on G0201100
# Error on G0201300
# Error on G0201500
# Error on G0201700
# Error on G0201880
# Error on G0201950
# Error on G0201980
# Error on G0202200
# Error on G0202300
# Error on G0202400
# Error on G0202750
# Error on G0202900
# Error on G0400010
# Error on G0400070
# Error on G0400090
# Error on G0400120
# Error on G0400170
# Error on G0400210
# Error on G0400250
# Error on G0500010
# Error on G0500030
# Error on G0500050
# Error on G0500170
# Error on G0500210
# Error on G0500230
# Error on G0500250
# Error on G0500270
# Error on G0500310
# Error on G0500350
# Error on G0500370
# Error on G0500430
# Error on G0500450
# Error on G0500470
# Error on G0500530
# Error on G0500570
# Error on G0500650
# Error on G0500710
# Error on G0500730
# Error on G0500790
# Error on G0500850
# Error on G0500870
# Error on G0500910
# Error on G0500930
# Error on G0500950
# Error on G0500970
# Error on G0500990
# Error on G0501010
# Error on G0501070
# Error on G0501130
# Error on G0501150
# Error on G0501170
# Error on G0501210
# Error on G0501230
# Error on G0501270
# Error on G0501290
# 100, Error on G0501370
# Error on G0501390
# Error on G0501410
# Error on G0501430
# Error on G0600030
# Error on G0600070
# Error on G0600110
# Error on G0600150
# Error on G0600170
# G1800970: (rmse=81.21018687408937, changepoint_prior_scale=0.1, seasonality_prior_scale=1.0)
# Error on G0600210
# Error on G0600230
# Error on G0600270
# Error on G0600330
# Error on G0600350
# G1701110: (rmse=56.54114220754974, changepoint_prior_scale=0.1, seasonality_prior_scale=0.01)
# Error on G0600490
# Error on G0600510
# Error on G0600530
# Error on G0600550
# Error on G0600690
# G1701110: (rmse=56.54114220754974, changepoint_prior_scale=0.1, seasonality_prior_scale=0.01)
# Error on G0600770
# Error on G0600790
# Error on G0600830
# G0400190: (rmse=149.52784059460504, changepoint_prior_scale=0.5, seasonality_prior_scale=1.0)
# Error on G0600890
# Error on G0600910
# Error on G0600950
# Error on G0601070
# Error on G0601090
# Error on G0601130
# Error on G0601150
# Error on G0800010
# Error on G0800090
# Error on G0800110
# Error on G0800130
# Error on G0800140
# Error on G0800170
# Error on G0800210
# Error on G0800230
# Error on G0800250
# Error on G0800270
# Error on G0800310
# Error on G0800330
# Error on G0800370
# Error on G0800450
# Error on G0800470
# Error on G0800490
# Error on G0800530
# Error on G0800570
# Error on G0800590
# Error on G0800610
# Error on G0800690
# Error on G0800710
# Error on G0800730
# Error on G0800790
# Error on G0800810
# Error on G0800830
# Error on G0800870
# Error on G0800910
# Error on G0800930
# Error on G0800950
# Error on G0801010
# Error on G0801030
# Error on G0801050
# Error on G0801070
# Error on G0801090
# Error on G0801110
# Error on G0801150
# Error on G0801210
# Error on G0801250
# Error on G0900010
# Error on G0900070
# Error on G0900130
# Error on G0900150
# Error on G1000030
# Error on G1000050
# Error on G1100010
# Error on G1200010
# Error on G1200030
# Error on G1200050
# Error on G1200130
# Error on G1200150
# G1701110: (rmse=56.54114220754974, changepoint_prior_scale=0.1, seasonality_prior_scale=0.01)
# Error on G1200230
# Error on G1200290
# Error on G1200310
# Error on G1200330
# Error on G1200350
# Error on G1200430
# Error on G1200450
# Error on G1200490
# Error on G1200530
# Error on G1200570
# Error on G1200590
# Error on G1200630
# Error on G1200670
# Error on G1200710
# Error on G1200770
# 200, Error on G1200790
# Error on G1200810
# Error on G1200860
# Error on G1200870
# Error on G1200930
# Error on G1200970
# Error on G1201070
# Error on G1201090
# Error on G1201110
# Error on G1201130
# Error on G1201190
# Error on G1201210
# Error on G1201250
# Error on G1201270
# Error on G1300010
# Error on G1300030
# Error on G1300050
# Error on G1300070
# Error on G1300090
# Error on G1300110
# Error on G1300170
# Error on G1300290
# Error on G1300310
# Error on G1300330
# Error on G1300370
# Error on G1300390
# Error on G1300430
# Error on G1300450
# Error on G1300490
# Error on G1300510
# Error on G1300550
# Error on G1300610
# Error on G1300630
# Error on G1300650
# Error on G1300690
# Error on G1300730
# Error on G1300750
# Error on G1300770
# Error on G1300790
# Error on G1300830
# Error on G1300930
# Error on G1300970
# Error on G1300990
# Error on G1301010
# Error on G1301050
# Error on G1301070
# Error on G1301150
# Error on G1301170
# Error on G1301190
# Error on G1301210
# Error on G1301250
# Error on G1301290
# Error on G1301310
# Error on G1301330
# Error on G1301390
# Error on G1301450
# Error on G1301470
# Error on G1301550
# Error on G1301630
# Error on G1301690
# Error on G1301730
# Error on G1301770
# Error on G1301790
# Error on G1301870
# Error on G1301890
# Error on G1301910
# Error on G1301930
# Error on G1301950
# Error on G1301970
# Error on G1301990
# Error on G1302010
# Error on G1302050
# Error on G1302090
# Error on G1302110
# Error on G1302130
# Error on G1302150
# Error on G1302170
# Error on G1302190
# Error on G1302210
# Error on G1302270
# Error on G1302290
# Error on G1302370
# Error on G1302390
# Error on G1302430
# Error on G1302450
# Error on G1302550
# Error on G1302590
# Error on G1302630
# Error on G1302650
# Error on G1302670
# Error on G1302690
# Error on G1302750
# Error on G1302770
# Error on G1302890
# Error on G1302950
# Error on G1302970
# Error on G1303010
# Error on G1303050
# Error on G1303070
# Error on G1303150
# 300, Error on G1303210
# Error on G1500010
# Error on G1500050
# Error on G1500070
# Error on G1600010
# Error on G1600030
# Error on G1600090
# Error on G1600110
# Error on G1600170
# Error on G1600190
# Error on G1600230
# Error on G1600250
# Error on G1600270
# Error on G1600290
# Error on G1600330
# Error on G1600370
# Error on G1600390
# Error on G1600410
# Error on G1600430
# Error on G1600470
# Error on G1600490
# Error on G1600530
# Error on G1600550
# Error on G1600590
# Error on G1600610
# Error on G1600630
# Error on G1600750
# Error on G1600770
# Error on G1600810
# Error on G1600830
# Error on G1700010
# Error on G1700030
# Error on G1700070
# Error on G1700090
# Error on G1700110
# Error on G1700170
# Error on G1700190
# Error on G1700210
# Error on G1700230
# Error on G1700250
# Error on G1700290
# Error on G1700330
# Error on G1700390
# Error on G1700510
# Error on G1700550
# Error on G1700590
# Error on G1700610
# Error on G1700630
# Error on G1700690
# Error on G1700710
# Error on G1700730
# Error on G1700750
# Error on G1700770
# Error on G1700890
# Error on G1700910
# Error on G1700930
# Error on G1700950
# Error on G1701010
# Error on G1701030
# Error on G1701050
# Error on G1701070
# G1701110: (rmse=56.54114220754974, changepoint_prior_scale=0.1, seasonality_prior_scale=0.01)
# Error on G1701230
# Error on G1701290
# Error on G1701330
# Error on G1701350
# Error on G1701430
# Error on G1701510
# Error on G1701530
# Error on G1701550
# Error on G1701570
# Error on G1701610
# Error on G1701630
# Error on G1701650
# Error on G1701670
# Error on G1701790
# Error on G1701890
# Error on G1701910
# Error on G1701930
# Error on G1701970
# Error on G1702030
# Error on G1800030
# Error on G1800050
# Error on G1800130
# Error on G1800150
# Error on G1800210
# Error on G1800230
# Error on G1800270
# Error on G1800290
# Error on G1800310
# Error on G1800330
# Error on G1800390
# Error on G1800410
# Error on G1800430
# Error on G1800450
# Error on G1800470
# Error on G1800490
# Error on G1800510
# Error on G1800530
# Error on G1800570
# 400, Error on G1800630
# Error on G1800670
# Error on G1800690
# Error on G1800730
# Error on G1800770
# Error on G1800810
# Error on G1800830
# Error on G1800870
# Error on G1800890
# Error on G1800910
# Error on G1800930
# Error on G1800950
# Error on G1801030
# Error on G1801050
# Error on G1801090
# Error on G1801110
# Error on G1801150
# Error on G1801210
# Error on G1801290
# Error on G1801350
# Error on G1801410
# Error on G1801490
# Error on G1801510
# Error on G1801530
# Error on G1801590
# Error on G1801610
# Error on G1801630
# Error on G1801690
# Error on G1801750
# Error on G1801830
# Error on G1900030
# Error on G1900050
# Error on G1900090
# Error on G1900110
# Error on G1900130
# Error on G1900210
# Error on G1900230
# Error on G1900290
# Error on G1900310
# Error on G1900330
# Error on G1900350
# Error on G1900390
# Error on G1900410
# Error on G1900430
# Error on G1900450
# Error on G1900470
# Error on G1900530
# Error on G1900570
# Error on G1900630
# Error on G1900650
# Error on G1900670
# Error on G1900690
# Error on G1900710
# Error on G1900730
# Error on G1900750
# Error on G1900790
# Error on G1900830
# Error on G1900890
# Error on G1900910
# Error on G1900970
# Error on G1900990
# Error on G1901030
# Error on G1901050
# Error on G1901110
# Error on G1901130
# Error on G1901170
# Error on G1901230
# Error on G1901250
# Error on G1901290
# Error on G1901330
# Error on G1901350
# Error on G1901370
# Error on G1901390
# Error on G1901410
# Error on G1901430
# Error on G1901450
# Error on G1901470
# Error on G1901510
# Error on G1901590
# Error on G1901630
# Error on G1901650
# Error on G1901670
# Error on G1901690
# Error on G1901710
# Error on G1901730
# Error on G1901790
# Error on G1901830
# Error on G1901910
# Error on G1901950
# Error on G1901970
# Error on G2000010
# Error on G2000030
# Error on G2000070
# Error on G2000090
# Error on G2000150
# Error on G2000170
# Error on G2000190
# Error on G2000230
# Error on G2000250
# Error on G2000290
# 500, Error on G2000310
# Error on G2000330
# Error on G2000370
# Error on G2000390
# Error on G2000410
# Error on G2000450
# Error on G2000470
# Error on G2000490
# Error on G2000530
# Error on G2000570
# Error on G2000690
# Error on G2000710
# Error on G2000750
# Error on G2000770
# Error on G2000790
# Error on G2000810
# Error on G2000830
# Error on G2000850
# Error on G2000870
# Error on G2000890
# Error on G2000930
# Error on G2000950
# Error on G2000970
# Error on G2000990
# Error on G2001010
# Error on G2001050
# Error on G2001070
# Error on G2001090
# Error on G2001130
# Error on G2001170
# Error on G2001190
# Error on G2001210
# Error on G2001250
# Error on G2001270
# Error on G2001290
# Error on G2001350
# Error on G2001370
# Error on G2001410
# Error on G2001430
# Error on G2001450
# Error on G2001470
# Error on G2001490
# Error on G2001510
# Error on G2001530
# Error on G2001570
# Error on G2001610
# Error on G2001630
# Error on G2001650
# Error on G2001690
# Error on G2001730
# Error on G2001750
# Error on G2001810
# Error on G2001830
# Error on G2001870
# Error on G2001890
# Error on G2001930
# Error on G2001970
# Error on G2001990
# Error on G2002010
# Error on G2002030
# Error on G2002050
# Error on G2002070
# Error on G2002090
# Error on G2100030
# Error on G2100050
# Error on G2100070
# Error on G2100090
# Error on G2100110
# Error on G2100130
# Error on G2100170
# Error on G2100230
# Error on G2100250
# Error on G2100310
# Error on G2100330
# Error on G2100350
# Error on G2100370
# Error on G2100390
# Error on G2100410
# Error on G2100450
# Error on G2100530
# Error on G2100550
# G1701110: (rmse=56.54114220754974, changepoint_prior_scale=0.1, seasonality_prior_scale=0.01)
# Error on G2100690
# Error on G2100750
# Error on G2100770
# Error on G2100850
# Error on G2100890
# Error on G2100930
# Error on G2100950
# Error on G2101010
# Error on G2101030
# Error on G2101090
# G1700430: (rmse=174.3024734636542, changepoint_prior_scale=0.01, seasonality_prior_scale=0.1)
# Error on G2101130
# Error on G2101170
# Error on G2101250
# Error on G2101310
# Error on G2101330
# Error on G2101350
# Error on G2101370
# 600, Error on G2101390
# Error on G2101430
# Error on G2101490
# Error on G2101510
# Error on G2101630
# Error on G2101650
# Error on G2101690
# Error on G2101730
# Error on G2101750
# Error on G2101770
# Error on G2101790
# Error on G2101830
# Error on G2101910
# Error on G2101970
# Error on G2101990
# Error on G2102010
# Error on G2102050
# Error on G2102070
# Error on G2102090
# Error on G2102150
# Error on G2102170
# Error on G2102190
# Error on G2102210
# Error on G2102250
# Error on G2102270
# Error on G2102330
# Error on G2102350
# Error on G2102370
# Error on G2200010
# Error on G2200030
# Error on G2200130
# Error on G2200150
# Error on G2200230
# Error on G2200250
# Error on G2200270
# Error on G2200310
# Error on G2200330
# Error on G2200350
# Error on G2200370
# Error on G2200410
# Error on G2200450
# Error on G2200470
# Error on G2200510
# Error on G2200530
# Error on G2200570
# Error on G2200650
# Error on G2200770
# Error on G2200790
# Error on G2200870
# Error on G2200890
# Error on G2200910
# Error on G2200930
# Error on G2200950
# Error on G2200970
# Error on G2200990
# Error on G2201030
# Error on G2201070
# Error on G2201090
# Error on G2201110
# Error on G2201170
# Error on G2201210
# Error on G2201230
# Error on G2201270
# Error on G2300110
# Error on G2300130
# Error on G2300170
# Error on G2300210
# Error on G2300270
# Error on G2300290
# Error on G2300310
# Error on G2400010
# Error on G2400050
# Error on G2400110
# Error on G2400130
# Error on G2400150
# Error on G2400190
# Error on G2400230
# Error on G2400250
# Error on G2400310
# Error on G2400350
# Error on G2400370
# Error on G2400390
# Error on G2400430
# Error on G2400470
# Error on G2500030
# Error on G2500050
# Error on G2500070
# Error on G2500110
# Error on G2500130
# Error on G2500150
# Error on G2500190
# Error on G2500210
# Error on G2500230
# Error on G2500270
# Error on G2600050
# Error on G2600130
# Error on G2600170
# Error on G2600290
# Error on G2600330
# Error on G2600350
# 700, Error on G2600370
# Error on G2600390
# Error on G2600450
# Error on G2600530
# Error on G2600570
# Error on G2600610
# Error on G2600730
# Error on G2600750
# Error on G2600770
# Error on G2600810
# Error on G2600830
# Error on G2600850
# Error on G2600870
# Error on G2600910
# Error on G2600950
# Error on G2600990
# Error on G2601050
# Error on G2601070
# Error on G2601090
# Error on G2601150
# Error on G2601190
# G1700430: (rmse=174.3024734636542, changepoint_prior_scale=0.01, seasonality_prior_scale=0.1)
# Error on G2601270
# Error on G2601310
# Error on G2601350
# Error on G2601390
# Error on G2601450
# Error on G2601510
# Error on G2601530
# Error on G2601550
# Error on G2601590
# Error on G2601630
# Error on G2601650
# Error on G2700010
# Error on G2700030
# Error on G2700050
# Error on G2700130
# Error on G2700190
# Error on G2700210
# Error on G2700250
# Error on G2700270
# Error on G2700290
# Error on G2700310
# Error on G2700330
# Error on G2700350
# Error on G2700450
# Error on G2700490
# Error on G2700510
# Error on G2700550
# Error on G2700570
# Error on G2700590
# Error on G2700610
# Error on G2700650
# Error on G2700690
# Error on G2700710
# Error on G2700730
# Error on G2700750
# Error on G2700770
# Error on G2700790
# Error on G2700830
# Error on G2700870
# Error on G2700930
# Error on G2700950
# Error on G2700990
# Error on G2701010
# Error on G2701050
# Error on G2701070
# Error on G2701190
# Error on G2701210
# Error on G2701230
# Error on G2701290
# Error on G2701390
# Error on G2701410
# Error on G2701450
# Error on G2701470
# Error on G2701490
# Error on G2701550
# Error on G2701570
# Error on G2701590
# G1701110: (rmse=56.54114220754974, changepoint_prior_scale=0.1, seasonality_prior_scale=0.01)
# Error on G2701730
# Error on G2800010
# Error on G2800030
# Error on G2800050
# Error on G2800070
# Error on G2800110
# Error on G2800130
# Error on G2800150
# Error on G2800170
# Error on G2800230
# Error on G2800330
# Error on G2800350
# Error on G2800370
# Error on G2800390
# Error on G2800430
# Error on G2800450
# Error on G2800470
# Error on G2800490
# Error on G2800510
# Error on G2800530
# 800, Error on G2800550
# Error on G2800590
# Error on G2800610
# Error on G2800670
# Error on G2800690
# Error on G2800710
# Error on G2800730
# Error on G2800770
# Error on G2800830
# Error on G2800850
# Error on G2800870
# Error on G2800930
# Error on G2801010
# Error on G2801030
# Error on G2801070
# Error on G2801090
# Error on G2801110
# Error on G2801130
# Error on G2801150
# Error on G2801170
# Error on G2801190
# Error on G2801250
# Error on G2801290
# Error on G2801330
# Error on G2801350
# Error on G2801370
# Error on G2801390
# Error on G2801410
# Error on G2801430
# Error on G2801490
# Error on G2801510
# Error on G2801550
# Error on G2801610
# Error on G2900030
# Error on G2900050
# Error on G2900070
# Error on G2900090
# Error on G2900110
# Error on G2900130
# Error on G2900150
# Error on G2900170
# Error on G2900210
# Error on G2900250
# Error on G2900290
# Error on G2900350
# Error on G2900390
# Error on G2900410
# Error on G2900450
# Error on G2900470
# Error on G2900550
# Error on G2900570
# Error on G2900610
# Error on G2900650
# Error on G2900730
# Error on G2900750
# Error on G2900810
# Error on G2900850
# Error on G2900890
# Error on G2900910
# Error on G2900930
# Error on G2900970
# Error on G2901010
# Error on G2901030
# Error on G2901050
# Error on G2901070
# Error on G2901090
# Error on G2901110
# Error on G2901130
# Error on G2901150
# Error on G2901190
# Error on G2901250
# Error on G2901290
# Error on G2901330
# Error on G2901350
# Error on G2901370
# Error on G2901430
# Error on G2901470
# Error on G2901490
# Error on G2901530
# Error on G2901550
# Error on G2901610
# Error on G2901650
# Error on G2901670
# Error on G2901710
# Error on G2901750
# Error on G2901770
# Error on G2901810
# Error on G2901830
# Error on G2901850
# Error on G2901950
# Error on G2901970
# Error on G2901990
# Error on G2902010
# Error on G2902050
# Error on G2902090
# Error on G2902130
# Error on G2902170
# Error on G2902190
# Error on G2902250
# Error on G2902270
# 900, Error on G2902290
# Error on G2905100
# Error on G3000010
# Error on G3000030
# Error on G3000050
# Error on G3000070
# Error on G3000110
# Error on G3000150
# Error on G3000170
# Error on G3000190
# Error on G3000230
# Error on G3000250
# Error on G3000270
# Error on G3000310
# Error on G3000330
# Error on G3000370
# Error on G3000390
# Error on G3000410
# Error on G3000450
# Error on G3000470
# Error on G3000490
# Error on G3000510
# Error on G3000550
# Error on G3000570
# Error on G3000590
# Error on G3000610
# Error on G3000650
# Error on G3000670
# Error on G3000690
# Error on G3000710
# Error on G3000730
# Error on G3000750
# Error on G3000770
# Error on G3000790
# Error on G3000810
# Error on G3000850
# Error on G3000870
# Error on G3000910
# Error on G3000930
# Error on G3000950
# Error on G3000970
# Error on G3001010
# Error on G3001030
# Error on G3001050
# Error on G3001070
# Error on G3001090
# Error on G3001110
# Error on G3100010
# Error on G3100050
# Error on G3100070
# Error on G3100090
# Error on G3100110
# Error on G3100150
# Error on G3100170
# Error on G3100210
# Error on G3100250
# Error on G3100290
# Error on G3100310
# Error on G3100330
# Error on G3100350
# Error on G3100370
# Error on G3100410
# Error on G3100430
# Error on G3100490
# Error on G3100510
# Error on G3100530
# Error on G3100550
# Error on G3100570
# Error on G3100590
# Error on G3100610
# Error on G3100630
# Error on G3100650
# Error on G3100690
# Error on G3100710
# Error on G3100730
# Error on G3100750
# Error on G3100770
# Error on G3100790
# Error on G3100810
# Error on G3100830
# Error on G3100850
# Error on G3100870
# Error on G3100890
# Error on G3100910
# Error on G3100930
# Error on G3100970
# Error on G3101030
# Error on G3101050
# Error on G3101070
# Error on G3101130
# Error on G3101150
# Error on G3101170
# Error on G3101190
# Error on G3101290
# Error on G3101330
# Error on G3101350
# Error on G3101370
# Error on G3101390
# Error on G3101410
# Error on G3101470
# 1000, Error on G3101490
# Error on G3101510
# Error on G3101550
# Error on G3101570
# Error on G3101610
# Error on G3101630
# Error on G3101650
# Error on G3101670
# Error on G3101690
# Error on G3101710
# Error on G3101750
# Error on G3101810
# Error on G3101830
# Error on G3200010
# Error on G3200050
# Error on G3200090
# Error on G3200110
# Error on G3200170
# Error on G3200190
# Error on G3200270
# Error on G3200290
# Error on G3300030
# Error on G3300090
# Error on G3300110
# Error on G3300130
# Error on G3400010
# Error on G3400070
# Error on G3400110
# Error on G3400130
# Error on G3400150
# Error on G3400170
# Error on G3400210
# Error on G3400330
# Error on G3400350
# Error on G3400370
# Error on G3400390
# Error on G3400410
# Error on G3500030
# Error on G3500110
# Error on G3500130
# Error on G3500170
# Error on G3500190
# Error on G3500210
# Error on G3500230
# Error on G3500280
# Error on G3500290
# Error on G3500330
# Error on G3500350
# Error on G3500370
# Error on G3500390
# Error on G3500450
# Error on G3500470
# Error on G3500490
# Error on G3500510
# Error on G3500530
# Error on G3500550
# Error on G3500570
# Error on G3500590
# Error on G3600030
# Error on G3600070
# Error on G3600110
# Error on G3600210
# Error on G3600290
# Error on G3600350
# Error on G3600370
# Error on G3600410
# Error on G3600450
# Error on G3600490
# Error on G3600630
# Error on G3600670
# Error on G3600690
# Error on G3600710
# Error on G3600790
# Error on G3600830
# Error on G3600870
# Error on G3600930
# Error on G3600950
# Error on G3601010
# Error on G3601130
# Error on G3601150
# Error on G3601210
# Error on G3700010
# Error on G3700030
# Error on G3700070
# Error on G3700090
# Error on G3700130
# Error on G3700190
# Error on G3700210
# Error on G3700250
# Error on G3700330
# Error on G3700350
# Error on G3700370
# Error on G3700390
# Error on G3700410
# Error on G3700430
# Error on G3700450
# Error on G3700490
# Error on G3700550
# Error on G3700570
# Error on G3700590
# 1100, Error on G3700650
# Error on G3700670
# Error on G3700710
# Error on G3700730
# Error on G3700810
# Error on G3700870
# Error on G3700890
# Error on G3700930
# Error on G3700990
# Error on G3701030
# Error on G3701090
# Error on G3701170
# Error on G3701190
# Error on G3701210
# Error on G3701230
# Error on G3701250
# Error on G3701290
# Error on G3701410
# Error on G3701450
# Error on G3701470
# Error on G3701550
# Error on G3701630
# Error on G3701650
# Error on G3701670
# Error on G3701730
# Error on G3701750
# Error on G3701770
# Error on G3701790
# Error on G3701810
# Error on G3701850
# Error on G3701870
# Error on G3701910
# Error on G3701950
# Error on G3701970
# Error on G3701990
# Error on G3800010
# Error on G3800070
# Error on G3800130
# Error on G3800150
# Error on G3800170
# Error on G3800190
# Error on G3800230
# Error on G3800250
# Error on G3800270
# Error on G3800290
# Error on G3800310
# Error on G3800330
# Error on G3800350
# Error on G3800370
# Error on G3800390
# Error on G3800410
# Error on G3800430
# Error on G3800470
# Error on G3800490
# Error on G3800510
# Error on G3800590
# Error on G3800630
# Error on G3800650
# Error on G3800670
# Error on G3800690
# Error on G3800810
# Error on G3800830
# Error on G3800850
# Error on G3800870
# Error on G3800910
# Error on G3800950
# Error on G3800970
# Error on G3800990
# Error on G3801010
# Error on G3801030
# Error on G3801050
# Error on G3900050
# Error on G3900070
# Error on G3900110
# Error on G3900150
# Error on G3900250
# Error on G3900290
# Error on G3900310
# Error on G3900330
# Error on G3900430
# Error on G3900450
# Error on G3900490
# Error on G3900510
# Error on G3900570
# G1700430: (rmse=174.3024734636542, changepoint_prior_scale=0.01, seasonality_prior_scale=0.1)
# Error on G3900630
# Error on G3900710
# Error on G3900730
# Error on G3900770
# Error on G3900790
# Error on G3900810
# Error on G3900870
# Error on G3900910
# Error on G3900930
# Error on G3900950
# Error on G3900970
# Error on G3900990
# Error on G3901010
# Error on G3901050
# Error on G3901070
# 1200, Error on G3901150
# Error on G3901190
# Error on G3901250
# Error on G3901290
# Error on G3901330
# Error on G3901370
# Error on G3901450
# Error on G3901470
# Error on G3901490
# Error on G3901550
# Error on G3901570
# Error on G3901590
# Error on G3901610
# Error on G3901730
# Error on G4000030
# Error on G4000070
# Error on G4000110
# Error on G4000130
# Error on G4000150
# Error on G4000170
# Error on G4000190
# Error on G4000210
# Error on G4000250
# Error on G4000350
# Error on G4000430
# Error on G4000450
# Error on G4000470
# Error on G4000550
# Error on G4000570
# Error on G4000610
# Error on G4000630
# Error on G4000670
# Error on G4000710
# Error on G4000770
# Error on G4000810
# Error on G4000830
# Error on G4000850
# Error on G4000870
# Error on G4000890
# Error on G4000910
# Error on G4000970
# Error on G4001030
# Error on G4001050
# Error on G4001130
# Error on G4001150
# Error on G4001210
# Error on G4001230
# Error on G4001250
# Error on G4001270
# Error on G4001290
# Error on G4001310
# Error on G4001330
# Error on G4001350
# Error on G4001370
# Error on G4001390
# G1700430: (rmse=174.3024734636542, changepoint_prior_scale=0.01, seasonality_prior_scale=0.1)
# Error on G4001450
# Error on G4001510
# Error on G4001530
# Error on G4100010
# Error on G4100090
# Error on G4100110
# Error on G4100150
# Error on G4100190
# Error on G4100210
# Error on G4100230
# Error on G4100290
# Error on G4100310
# Error on G4100370
# Error on G4100410
# Error on G4100470
# Error on G4100490
# Error on G4100550
# Error on G4100570
# Error on G4100590
# Error on G4100610
# Error on G4100630
# Error on G4100690
# Error on G4200090
# Error on G4200130
# Error on G4200150
# Error on G4200170
# Error on G4200190
# Error on G4200210
# Error on G4200230
# Error on G4200250
# Error on G4200270
# Error on G4200290
# Error on G4200310
# Error on G4200330
# Error on G4200350
# Error on G4200390
# Error on G4200410
# Error on G4200430
# Error on G4200550
# Error on G4200570
# Error on G4200630
# Error on G4200710
# Error on G4200750
# Error on G4200790
# 1300, Error on G4200810
# Error on G4200850
# Error on G4200870
# Error on G4200890
# Error on G4200910
# Error on G4200930
# Error on G4200950
# Error on G4200970
# Error on G4200990
# Error on G4201050
# Error on G4201090
# Error on G4201130
# Error on G4201150
# Error on G4201170
# Error on G4201190
# Error on G4201210
# Error on G4201230
# Error on G4201270
# Error on G4201310
# Error on G4201330
# Error on G4400030
# Error on G4400090
# Error on G4500050
# Error on G4500070
# Error on G4500090
# Error on G4500130
# Error on G4500150
# Error on G4500190
# Error on G4500210
# Error on G4500230
# Error on G4500330
# Error on G4500410
# Error on G4500430
# Error on G4500450
# Error on G4500550
# Error on G4500570
# Error on G4500610
# Error on G4500630
# Error on G4500650
# Error on G4500670
# Error on G4500710
# Error on G4500730
# Error on G4500750
# Error on G4500770
# Error on G4500810
# Error on G4500830
# Error on G4500850
# Error on G4500890
# Error on G4500910
# Error on G4600050
# Error on G4600070
# Error on G4600090
# Error on G4600150
# Error on G4600170
# Error on G4600190
# Error on G4600210
# Error on G4600250
# Error on G4600290
# Error on G4600310
# Error on G4600350
# Error on G4600390
# Error on G4600430
# Error on G4600450
# Error on G4600470
# Error on G4600490
# Error on G4600510
# Error on G4600530
# Error on G4600550
# Error on G4600570
# Error on G4600590
# Error on G4600630
# Error on G4600650
# Error on G4600670
# Error on G4600690
# Error on G4600710
# Error on G4600730
# Error on G4600750
# Error on G4600770
# Error on G4600810
# Error on G4600850
# Error on G4600890
# Error on G4600910
# Error on G4600950
# Error on G4600970
# Error on G4601010
# Error on G4601070
# Error on G4601090
# Error on G4601110
# Error on G4601170
# Error on G4601190
# Error on G4601230
# Error on G4601270
# Error on G4601290
# Error on G4601370
# Error on G4700110
# Error on G4700150
# Error on G4700210
# Error on G4700230
# Error on G4700250
# Error on G4700270
# 1400, Error on G4700350
# Error on G4700390
# Error on G4700410
# Error on G4700510
# Error on G4700530
# Error on G4700590
# Error on G4700650
# Error on G4700690
# Error on G4700710
# Error on G4700730
# Error on G4700790
# Error on G4700830
# Error on G4700850
# Error on G4700870
# Error on G4700890
# Error on G4700910
# Error on G4700930
# Error on G4700990
# Error on G4701070
# Error on G4701090
# Error on G4701110
# Error on G4701130
# Error on G4701170
# Error on G4701190
# Error on G4701210
# Error on G4701230
# Error on G4701250
# Error on G4701270
# Error on G4701290
# Error on G4701310
# Error on G4701330
# Error on G4701370
# Error on G4701410
# Error on G4701430
# Error on G4701490
# Error on G4701510
# Error on G4701590
# Error on G4701610
# Error on G4701630
# Error on G4701650
# Error on G4701690
# Error on G4701730
# Error on G4701750
# Error on G4701770
# Error on G4701790
# Error on G4701850
# Error on G4701870
# Error on G4701890
# Error on G4800030
# Error on G4800050
# Error on G4800070
# Error on G4800090
# Error on G4800110
# Error on G4800130
# Error on G4800150
# Error on G4800170
# Error on G4800190
# Error on G4800230
# Error on G4800250
# Error on G4800310
# Error on G4800330
# Error on G4800430
# Error on G4800450
# Error on G4800490
# Error on G4800530
# Error on G4800570
# Error on G4800590
# Error on G4800630
# Error on G4800650
# Error on G4800670
# Error on G4800710
# Error on G4800790
# Error on G4800810
# Error on G4800830
# Error on G4800870
# Error on G4800910
# Error on G4800950
# Error on G4800970
# Error on G4800990
# Error on G4801010
# Error on G4801030
# Error on G4801050
# Error on G4801070
# Error on G4801210
# Error on G4801250
# Error on G4801270
# Error on G4801290
# Error on G4801310
# Error on G4801330
# Error on G4801370
# Error on G4801410
# Error on G4801430
# Error on G4801450
# Error on G4801470
# Error on G4801510
# Error on G4801530
# Error on G4801550
# Error on G4801590
# Error on G4801610
# Error on G4801630
# 1500, Error on G4801670
# Error on G4801690
# Error on G4801730
# Error on G4801750
# Error on G4801770
# Error on G4801830
# Error on G4801850
# Error on G4801870
# Error on G4801910
# Error on G4801930
# Error on G4801950
# Error on G4801970
# Error on G4802030
# Error on G4802050
# Error on G4802090
# Error on G4802110
# Error on G4802250
# Error on G4802290
# Error on G4802350
# Error on G4802370
# Error on G4802390
# Error on G4802430
# Error on G4802470
# Error on G4802490
# Error on G4802530
# Error on G4802550
# Error on G4802570
# Error on G4802610
# Error on G4802630
# Error on G4802670
# Error on G4802690
# Error on G4802710
# Error on G4802750
# Error on G4802790
# Error on G4802830
# Error on G4802850
# Error on G4802930
# Error on G4802950
# Error on G4802990
# Error on G4803010
# Error on G4803030
# Error on G4803050
# Error on G4803090
# Error on G4803110
# Error on G4803150
# Error on G4803170
# Error on G4803190
# Error on G4803210
# Error on G4803230
# Error on G4803250
# Error on G4803270
# Error on G4803310
# Error on G4803330
# Error on G4803350
# Error on G4803390
# Error on G4803410
# Error on G4803430
# Error on G4803450
# Error on G4803470
# Error on G4803490
# Error on G4803510
# G1701110: (rmse=56.54114220754974, changepoint_prior_scale=0.1, seasonality_prior_scale=0.01)
# Error on G4803570
# Error on G4803590
# Error on G4803610
# Error on G4803630
# Error on G4803650
# Error on G4803710
# Error on G4803730
# Error on G4803750
# Error on G4803770
# Error on G4803810
# Error on G4803830
# Error on G4803850
# Error on G4803910
# Error on G4803930
# Error on G4803970
# Error on G4804030
# Error on G4804050
# Error on G4804110
# Error on G4804170
# Error on G4804190
# Error on G4804210
# Error on G4804250
# Error on G4804270
# Error on G4804290
# Error on G4804310
# Error on G4804330
# Error on G4804350
# Error on G4804370
# Error on G4804390
# Error on G4804410
# Error on G4804430
# Error on G4804450
# Error on G4804470
# Error on G4804490
# Error on G4804610
# Error on G4804630
# Error on G4804690
# Error on G4804710
# 1600, Error on G4804730
# Error on G4804750
# Error on G4804770
# Error on G4804810
# Error on G4804870
# Error on G4804910
# Error on G4804930
# Error on G4804950
# Error on G4804970
# Error on G4804990
# Error on G4805010
# Error on G4805030
# Error on G4805050
# Error on G4900010
# Error on G4900090
# Error on G4900110
# Error on G4900230
# Error on G4900250
# Error on G4900290
# Error on G4900310
# Error on G4900330
# Error on G4900370
# Error on G4900390
# Error on G4900450
# Error on G4900470
# Error on G4900530
# Error on G4900550
# Error on G5000070
# Error on G5000090
# Error on G5000110
# Error on G5000130
# Error on G5000150
# Error on G5000170
# Error on G5000190
# Error on G5000270
# Error on G5100070
# Error on G5100110
# Error on G5100130
# Error on G5100150
# Error on G5100170
# Error on G5100210
# Error on G5100230
# Error on G5100270
# Error on G5100290
# Error on G5100310
# Error on G5100330
# Error on G5100350
# Error on G5100360
# Error on G5100370
# G1701110: (rmse=56.54114220754974, changepoint_prior_scale=0.1, seasonality_prior_scale=0.01)
# Error on G5100450
# Error on G5100470
# Error on G5100490
# Error on G5100570
# Error on G5100610
# Error on G5100650
# Error on G5100670
# Error on G5100690
# Error on G5100710
# Error on G5100750
# Error on G5100770
# Error on G5100790
# Error on G5100830
# Error on G5100870
# Error on G5100910
# Error on G5100950
# Error on G5100970
# Error on G5100990
# Error on G5101010
# Error on G5101070
# Error on G5101150
# Error on G5101210
# Error on G5101250
# Error on G5101270
# Error on G5101310
# Error on G5101330
# Error on G5101350
# Error on G5101370
# Error on G5101390
# Error on G5101450
# Error on G5101470
# Error on G5101570
# Error on G5101630
# Error on G5101650
# Error on G5101670
# Error on G5101710
# Error on G5101730
# Error on G5101750
# Error on G5101770
# Error on G5101790
# Error on G5101830
# Error on G5101850
# Error on G5101870
# Error on G5101950
# Error on G5101970
# Error on G5101990
# Error on G5105200
# Error on G5105400
# Error on G5105700
# Error on G5106000
# 1700, Error on G5106100
# Error on G5106300
# Error on G5106600
# Error on G5106700
# Error on G5106780
# Error on G5106830
# Error on G5106900
# Error on G5107200
# Error on G5107350
# Error on G5107500
# Error on G5107600
# Error on G5107900
# G1701110: (rmse=56.54114220754974, changepoint_prior_scale=0.1, seasonality_prior_scale=0.01)
# Error on G5108200
# Error on G5108300
# Error on G5108400
# Error on G5300010
# Error on G5300030
# Error on G5300050
# Error on G5300090
# Error on G5300110
# Error on G5300130
# Error on G5300190
# Error on G5300230
# Error on G5300250
# Error on G5300270
# Error on G5300290
# Error on G5300310
# Error on G5300410
# Error on G5300430
# Error on G5300490
# Error on G5300530
# Error on G5300550
# Error on G5300570
# Error on G5300630
# Error on G5300650
# Error on G5300670
# Error on G5300690
# Error on G5300710
# Error on G5300730
# Error on G5300750
# Error on G5300770
# Error on G5400010
# Error on G5400030
# Error on G5400050
# Error on G5400070
# Error on G5400130
# Error on G5400150
# Error on G5400170
# Error on G5400250
# Error on G5400270
# Error on G5400290
# Error on G5400330
# Error on G5400350
# Error on G5400370
# Error on G5400430
# Error on G5400450
# Error on G5400490
# Error on G5400510
# Error on G5400530
# Error on G5400570
# Error on G5400630
# Error on G5400670
# Error on G5400750
# Error on G5400770
# Error on G5400850
# Error on G5400870
# Error on G5400890
# Error on G5400970
# Error on G5400990
# Error on G5401010
# Error on G5401030
# Error on G5500130
# Error on G5500150
# Error on G5500170
# Error on G5500210
# Error on G5500230
# Error on G5500270
# Error on G5500290
# Error on G5500330
# Error on G5500350
# Error on G5500370
# Error on G5500390
# Error on G5500530
# Error on G5500570
# Error on G5500630
# Error on G5500650
# Error on G5500730
# Error on G5500750
# Error on G5500780
# Error on G5500810
# Error on G5500870
# Error on G5500890
# Error on G5500930
# Error on G5500950
# Error on G5501010
# Error on G5501070
# Error on G5501090
# Error on G5501110
# Error on G5501130
# 1800, Error on G5501150
# Error on G5501170
# Error on G5501210
# Error on G5501330
# Error on G5501410
# Error on G5600010
# Error on G5600030
# Error on G5600070
# Error on G5600110
# Error on G5600130
# Error on G5600150
# Error on G5600210
# Error on G5600270
# Error on G5600290
# Error on G5600310
# Error on G5600350
# Error on G5600410
# (('G0100970', 72.88429450499825),
#  ('G0600190', 74.34747477294877),
#  ('G0600470', 75.01832640799694),
#  ('G0600750', 75.16081715305336),
#  ('G0600850', 75.130009528948))

# %%
gis_joins = []
times = []

for r, t in results:
    gis_joins.append(r)
    times.append(t)
    
times_0_15_df = pd.DataFrame(zip(gis_joins, times), columns=['GISJOIN', 'time'])
# times_0_15_df.to_csv('ucc-21/child_training_tl_times_0_15.csv', index=False)
times_0_15_df
# Out:
#      GISJOIN       time
# 0   G0100970  72.884295
# 1   G0600190  74.347475
# 2   G0600470  75.018326
# 3   G0600750  75.160817
# 4   G0600850  75.130010
# 5   G1200210  74.434802
# 6   G1701190  74.984225
# 7   G2100670  75.101669
# 8   G2101110  75.236491
# 9   G2601250  75.215337
# 10  G2701630  75.220230
# 11  G3900610  75.054709
# 12  G4001430  74.983301
# 13  G4803550  75.176027
# 14  G5100410  75.191083
# 15  G5108100  75.200069
